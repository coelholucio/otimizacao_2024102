# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sympy import diff
from sympy import symbols
import sympy as sp
import matplotlib.pyplot as plt

# %%
#https://people.duke.edu/~ccc14/sta-663-2016/13_Optimization.html

# %%
def func(X):
    x = X[0]
    y = X[1]
    L = X[2] # this is the multiplier. lambda is a reserved keyword in python
    return x + y + L * (x**2 + y**2 - 1)

def dfunc(X):
    dLambda = np.zeros(len(X))
    h = 1e-3 # this is the step size used in the finite difference.
    for i in range(len(X)):
        dX = np.zeros(len(X))
        dX[i] = h
        dLambda[i] = (func(X+dX)-func(X-dX))/(2*h);
    return dLambda

from scipy.optimize import fsolve

# this is the max
X1 = fsolve(dfunc, [1, 1, 0])
print(X1), print(func(X1))

# this is the min
X2 = fsolve(dfunc, [-1, -1, 0])
print(X2), print(func(X2))
# Out:
# [ 0.70710678  0.70710678 -0.70710678]
# 1.4142135623730951
# [-0.70710678 -0.70710678  0.70710678]
# -1.414213562373095

# %%
L = symbols('L')
h = 1e-3
y = x + y + L * (x**2 + y**2 - 1)
forward_diff = np.diff(y)/h 
forward_diff
# Out:
# array([3.33288951992472e-10*L + 0.999500000041564,
#        5.00000041370185e-9*L + 0.998500000624958,
#        2.16666684593747e-8*L + 0.997500002708485, ...,
#        12.5663705876491*L + 1.00268530384007,
#        12.5663706074164*L + 1.00168530631173,
#        12.5663706137047*L + 1.00068530709763], dtype=object)

# %%
def f(x):
    return x**3-3*x+1
x = np.linspace(-3,3,100)
plt.axhline(0, c='red')
plt.plot(x, f(x));

# %%
def func(X):
    x = X[0]
    L = X[1] # this is the multiplier. lambda is a reserved keyword in python
    return 3*x**2-3 + L *(x**3-3*x+1) 

def dfunc(X):
    dLambda = np.zeros(len(X))
    h = 1e-3 # this is the step size used in the finite difference.
    for i in range(len(X)):
        dX = np.zeros(len(X))
        dX[i] = h
        dLambda[i] = (func(X+dX)-func(X-dX))/(2*h);
    return dLambda

from scipy.optimize import fsolve

# this is the max
X1 = fsolve(dfunc, [3,0])
print(X1)
print(func(X1))
# Out:
# [ 1.53208889 -2.27431552]
# 4.0418890660015805

# %% [markdown]
# #Exemplo earnix

# %%
# Define the demand function
def demand(x,price):
    comb_linear =0.64+0.4*x - 0.005*price
    d = np.exp(comb_linear)/((1+np.exp(comb_linear)))
    return d

# %%
demanda =demand(1,250)
print('Demanda Cliente 1: %s' % round(demanda,4))
# Out:
# Demanda Cliente 1: 0.4477

# %%
demanda =demand(0,300)
print('Demanda Cliente 2: %s' % round(demanda,4))
# Out:
# Demanda Cliente 2: 0.2973

# %%
demand(0,300)+demand(1,250)
# Out:
# 0.7450314360809431

# %%
# Define the demand function
def demand(X):
    x=X[0]
    price=X[1]
    d = np.exp(0.64+0.4*x - 0.005*price)/((1+np.exp(0.64+0.4*x - 0.005*price)))
    return d

# %%
demand(0,300)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[266], line 1
# ----> 1 demand(0,300)
#
# Cell In[264], line 5, in demand(X, Preco)
#       3 demanda=[]
#       4 demanda = np.exp(0.64+0.4*X - 0.005*Preco)/((1+np.exp(0.64+0.4*X - 0.005*Preco)))
# ----> 5 d = demanda.append(demanda)
#       6 return d
#
# AttributeError: 'numpy.float64' object has no attribute 'append'

# %%
#derivada da função logistica
#gx = 1/(1+np.exp(-x))
#dgx = (1/(1+np.exp(-x)))* L * (1-(1/(1+np.exp(-x))))
#( np.exp(1.04)*np.exp(-0.005*p1) - 0.005*p1 + 1) + (L + 150)*0.005 = 0   derivada
#( np.exp(0.64)*np.exp(-0.005*p2) - 0.005*p2 + 1) + (L + 150)*0.005 = 0  derivada

# %%
def func(X):
    p1 = X[0]
    p2 = X[1]
    L =  X[2] # this is the multiplier. lambda is a reserved keyword in python
    return  (np.exp(1.04)*np.exp(-0.005*p1) - 0.005*p1 + 1) + (L + 150)*0.005 + (np.exp(0.64)*np.exp(-0.005*p2) - 0.005*p2 + 1) + (L + 150)*0.005

# %%
def func(X):
    p1 = X[0]
    #p2 = X[1]
    L = X[1] # this is the multiplier. lambda is a reserved keyword in python
    #return ( (np.exp(1.04)*np.exp(-0.005*p1) - 0.005*p1 + 1) + (L + 150)*0.005 + ( np.exp(0.64)*np.exp(-0.005*p2) - 0.005*p2 + 1) + (L + 150)*0.005)
    return  (np.exp(1.04)*np.exp(-0.005*p1) - 0.005*p1 + 1) + (L + 150)*0.005

# %%
def func(X):
    #p1 = X[0]
    p2 = X[1]
    L = X[0] # this is the multiplier. lambda is a reserved keyword in python
    #return ( (np.exp(1.04)*np.exp(-0.005*p1) - 0.005*p1 + 1) + (L + 150)*0.005 + ( np.exp(0.64)*np.exp(-0.005*p2) - 0.005*p2 + 1) + (L + 150)*0.005)
    return ( np.exp(0.64)*np.exp(-0.005*p2) - 0.005*p2 + 1) + (L + 150)*0.005

# %%
def dfunc(X):
    dLambda = np.zeros(len(X))
    h = 1e-3 # this is the step size used in the finite difference.
    for i in range(len(X)):
        dX = np.zeros(len(X))
        dX[i] = h
        dLambda[i] = (func(X+dX)-func(X-dX))/(2*h);
    return dLambda

from scipy.optimize import fsolve

# this is the max
X1 = fsolve(dfunc, [5,5,0])
print(X1)
print(func(X1))
# Out:
# [ 5755.33920123 40378.87823104  2458.91978736]
# -202.58188928775792
# C:\ProgramData\anaconda3\lib\site-packages\scipy\optimize\_minpack_py.py:178: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)

# %%
61.9911926883365-265.7964200326616
# Out:
# -203.80522734432512

# %%
def square(X):
    x = X[0]
    x_squared = x**2
    return x_squared

# %%
def dfunc1(X):
    dLambda = np.zeros(len(X))
    h = 1e-3 # this is the step size used in the finite difference.
    for i in range(len(X)):
        dX = np.zeros(len(X))
        dX[i] = h
        dLambda[i] = (square(X+dX)-square(X-dX))/(2*h);
    return dLambda

from scipy.optimize import fsolve

# this is the max
X1 = fsolve(dfunc1, [2])
print(X1)
print(square(X1))
# Out:
# [3.26107685e-20]
# 1.0634622201574495e-39

# %%
# Define the demand function
def f1(x,price1):
    return np.exp(0.64+0.4*x - 0.005*price1)/((1+np.exp(0.64+0.4*x - 0.005*price1)))

# Define the demand function
def f2(x,price2):
    return np.exp(0.64+0.4*x - 0.005*price2)/((1+np.exp(0.64+0.4*x - 0.005*price2)))

# %%
print(f1(1,250))
print(f2(0,300))
# Out:
# 0.4476920904256747
# 0.2973393456552685

# %%
(np.exp(1.04)*np.exp(- 0.005*premio1))/(1+((np.exp(1.04)*np.exp(- 0.005*premio1))))


/((1+np.exp(1.04- 0.005*premio1)))
(np.exp(0.64 - 0.005*premio2))/((1+np.exp(0.64- 0.005*premio2)))

gx = (np.exp(1.04 - 0.005*premio1))/((1+np.exp(1.04 - 0.005*premio1)))+(np.exp(0.64 - 0.005*premio2))/((1+np.exp(0.64- 0.005*premio2)))-0.69647

(((np.exp(1.04 - 0.005*premio1))/((1+np.exp(1.04 - 0.005*premio1)))*(premio1-250))*(premio1-150))

(((np.exp(0.64 - 0.005*premio2))/((1+np.exp(0.64 - 0.005*premio2)))*(premio2-300))*(premio2-150))


f =((((sp.exp(1.04)*sp.exp(-0.005*premio1) ) /(1+sp.exp(1.04)*sp.exp(-0.005*premio1)))*(premio1-250)  )*(premio1-150)) +((((sp.exp(0.64)*sp.exp(-0.005*premio2) ) /(1+sp.exp(0.64)*sp.exp(-0.005*premio2)))*(premio2-300)  )*(premio2-150))-L*(((sp.exp(1.04)*sp.exp(-0.005*premio1) ) /(1+sp.exp(1.04)*sp.exp(-0.005*premio1))) + ((sp.exp(0.64)*sp.exp(-0.005*premio2) ) /(1+sp.exp(0.64)*sp.exp(-0.005*premio2)))-0.745031436)

# %%
(((np.exp(1.04 - 0.005*premio1))/((1+np.exp(1.04 - 0.005*premio1)))*(premio1-250))*(premio1-150)) + (((np.exp(0.64 - 0.005*premio2))/((1+np.exp(0.64 - 0.005*premio2)))*(premio2-300))*(premio2-150)) -(np.exp(1.04 - 0.005*premio1))/((1+np.exp(1.04 - 0.005*premio1)))+(np.exp(0.64 - 0.005*premio2))/((1+np.exp(0.64- 0.005*premio2)))-0.69647

# %%
#from sympy import diff
#from sympy import symbols
#import autograd.numpy as ag
#f_prime = grad(f,x)
#result=f_prime(1,100)

# %%
# Define the demand function
def f2(x,price):
    return 1/(1+np.exp(-1*(0.64+0.4*x - 0.005*price)))

# %%
f2(1,250)
# Out:
# 0.4476920904256748

# %%
from sympy import symbols, diff
import math as mt
import sympy as sp
#2. Define the variables and the function:

# %%
x = symbols('x')  # Define the variable
f = 2*x**3 + 5*x**2 - 3*x + 2  # Define the function

# %%
#3. Calculate the derivative:

f_prime = diff(f, x)  # Calculate the derivative of f with respect to x
#4. Print the derivative:

print(f_prime)  # Display the derivative
# Out:
# 6*x**2 + 10*x - 3

# %%
x = symbols('x')
f = sp.exp(x)
f = sp.log(x)
f_prime = diff(f, x)
print(f_prime)
# Out:
# 1/x

# %%
x = symbols('x')
premio = symbols('premio')
f = (sp.exp(0.64+0.4*x)*sp.exp(premio))/(1 + sp.exp(0.64+0.4*x)*sp.exp(premio))-0.69647

# %%
f_prime = diff(f, x)
print(f_prime)
# Out:
# 0.758592351721981*exp(premio)*exp(0.4*x)/(1.89648087930495*exp(premio)*exp(0.4*x) + 1) - 0.4*exp(2*premio)*exp(0.8*x)/(exp(premio)*exp(0.4*x) + 0.527292424043049)**2

# %%
x = symbols('x')
premio1 = symbols('premio1')
premio2 = symbols('premio2')

f =(sp.exp(1.04)*sp.exp(-0.005*premio1))/(1+sp.exp(1.04)*sp.exp(-0.005*premio1))+(sp.exp(0.64)*sp.exp(-0.005*premio2))/(1+sp.exp(1.04)*sp.exp(-0.005*premio2)) - 0.69647
f_prime = diff(f, premio1)
print(f_prime)
# Out:
# -0.0141460850717578*exp(-0.005*premio1)/(1 + 2.82921701435156*exp(-0.005*premio1)) + 0.005*exp(-0.01*premio1)/(0.35345468195878 + exp(-0.005*premio1))**2

# %%
x = symbols('x')
P1 = symbols('P1')
P2 = symbols('P2')
L = symbols('L')

f = -0.0025 * 𝑃1**2 - 0.015 * 𝑃2**2 + 2.65 * 𝑃1 + 1.725 * 𝑃2 - 880 - L * (0.925 - 0.00125 * 𝑃1 - 0.00075 * 𝑃2)
f_prime_L = diff(f, L)
f_prime_P1 = diff(f, P1)
f_prime_P2 = diff(f, P2)
print(f_prime_L)
print(f_prime_P1)
print(f_prime_P2)
# Out:
# 0.00125*P1 + 0.00075*P2 - 0.925
# 0.00125*L - 0.005*P1 + 2.65
# 0.00075*L - 0.03*P2 + 1.725

# %%
x, y = symbols('x y')
f = x**2 + 3*y**2 + 2*x*y
f_partial_x = diff(f, x)
f_partial_y = diff(f, y)
print(f_partial_x)
print(f_partial_y)
# Out:
# 2*x + 2*y
# 2*x + 6*y

# %%
def func(X):
    P1 = X[0]
    P2 = X[1]
    L  = X[2] # this is the multiplier. lambda is a reserved keyword in python
    return -0.0025 * 𝑃1**2 - 0.015 * 𝑃2**2 + 2.65 * 𝑃1 + 1.725 * 𝑃2 - 880 - L * (0.925 - 0.00125 * 𝑃1 - 0.00075 * 𝑃2)
    #return -0.0025 * 𝑃1**2 - 0.015 * 𝑃2**2 + 2.65 * 𝑃1 + 1.725 * 𝑃2 - 880 - L * (0.925 - 0.00125 * 𝑃1 - 0.00075 * 𝑃2)
    #return -0.0025 * 𝑃1**2 - 0.015 * 𝑃2**2 + 2.65 * 𝑃1 + 1.725 * 𝑃2 - 880 - L * (0.925 - 0.00125 * 𝑃1 - 0.00075 * 𝑃2)

def dfunc(X):
    dLambda = np.zeros(len(X))
    h = 1e-3 # this is the step size used in the finite difference.
    for i in range(len(X)):
        dX = np.zeros(len(X))
        dX[i] = h
        dLambda[i] = (func(X+dX)-func(X-dX))/(2*h);
    return dLambda

from scipy.optimize import fsolve

#this is the max
X1 = fsolve(dfunc, [500, 400, 0])
print(X1) ,
print(func(X1))
# Out:
# [695.56603774  74.05660378 662.26415104]
# -200.79834905660397

# %%
x = symbols('x')
premio1 = symbols('premio1')
premio2 = symbols('premio2')

f =(sp.exp(1.04)*sp.exp(-0.005*premio1) + 1) +  (L + 150)*0.005
f_prime = diff(f, premio1)
print(f_prime)


def func(X):
    P1 = X[0]
    P2 = X[1]
    L  = X[2] # this is the multiplier. lambda is a reserved keyword in python
    #return -0.0025 * 𝑃1**2 - 0.015 * 𝑃2**2 + 2.65 * 𝑃1 + 1.725 * 𝑃2 - 880 - L * (0.925 - 0.00125 * 𝑃1 - 0.00075 * 𝑃2)
    #return -0.0025 * 𝑃1**2 - 0.015 * 𝑃2**2 + 2.65 * 𝑃1 + 1.725 * 𝑃2 - 880 - L * (0.925 - 0.00125 * 𝑃1 - 0.00075 * 𝑃2)
    #return -0.0025 * 𝑃1**2 - 0.015 * 𝑃2**2 + 2.65 * 𝑃1 + 1.725 * 𝑃2 - 880 - L * (0.925 - 0.00125 * 𝑃1 - 0.00075 * 𝑃2)
    #return (sp.exp(1.04)*sp.exp(-0.005*P1) + 1) +  (L + 150)*0.005
    return (sp.exp(0.64)*sp.exp(-0.005*P2) + 1) +  (L + 150)*0.005

def dfunc(X):
    dLambda = np.zeros(len(X))
    h = 1e-3 # this is the step size used in the finite difference.
    for i in range(len(X)):
        dX = np.zeros(len(X))
        dX[i] = h
        dLambda[i] = (func(X+dX)-func(X-dX))/(2*h);
    return dLambda

from scipy.optimize import fsolve

#this is the max
X1 = fsolve(dfunc, [10, 10, 0])
print(X1) ,
print(func(X1))
# Out:
# -0.0141460850717578*exp(-0.005*premio1)
# [1.00000000e+01 1.31815204e+03 2.76328161e+04]
# 139.916684118914

# %% [markdown]
# ##################

# %%
x = symbols('x')
C = symbols('C')
a = symbols('a')
b = symbols('b')
b = symbols('b')
L = symbols('L')
premio1 = symbols('premio1')
premio2 = symbols('premio2')

#f =np.exp(0.64 - 0.005*premio1)/(1+np.exp(0.64 - 0.005*premio1))

f =((((sp.exp(1.04)*sp.exp(-0.005*premio1) ) /(1+sp.exp(1.04)*sp.exp(-0.005*premio1)))*(premio1-250)  )*(premio1-150)) +((((sp.exp(0.64)*sp.exp(-0.005*premio2) ) /(1+sp.exp(0.64)*sp.exp(-0.005*premio2)))*(premio2-300)  )*(premio2-150))-L*(((sp.exp(1.04)*sp.exp(-0.005*premio1) ) /(1+sp.exp(1.04)*sp.exp(-0.005*premio1))) + ((sp.exp(0.64)*sp.exp(-0.005*premio2) ) /(1+sp.exp(0.64)*sp.exp(-0.005*premio2)))-0.745031436)


#f =(
#    ( ((sp.exp(1.04)*sp.exp(-0.005*premio1) ) /(1+sp.exp(1.04)*sp.exp(-0.005*premio1)))*sp.exp(premio1-250) )*sp.exp(premio1-150) +  
#    ( ((sp.exp(0.64)*sp.exp(-0.005*premio2) ) /(1+sp.exp(0.64)*sp.exp(-0.005*premio2)))*sp.exp(premio2-300) )*sp.exp(premio2-150)
#)-L*(
#    ( ((sp.exp(1.04)*sp.exp(-0.005*premio1) ) /(1+sp.exp(1.04)*sp.exp(-0.005*premio1)))*sp.exp(premio1-250) )*sp.exp(premio1-150) +  
#    ( ((sp.exp(0.64)*sp.exp(-0.005*premio2) ) /(1+sp.exp(0.64)*sp.exp(-0.005*premio2)))*sp.exp(premio2-300) )*sp.exp(premio2-150)
#)
 #f =(((((sp.exp(1.04)*sp.exp(-0.005*premio1) ) /(1+sp.exp(1.04)*sp.exp(-0.005*premio1)) )*(premio1-250))*(premio1-150)) +
#   ((((sp.exp(0.64)*sp.exp(-0.005*premio2) ) /(1+sp.exp(0.64)*sp.exp(-0.005*premio2)) )*(premio2-300))*(premio2-150)) )-L*(((((sp.exp(1.04)*sp.exp(-0.005*premio1) ) /(1+sp.exp(1.04)*sp.exp(-0.005*premio1)) )*(premio1-250))*(premio1-150)) +
#   ((((sp.exp(0.64)*sp.exp(-0.005*premio2) ) /(1+sp.exp(0.64)*sp.exp(-0.005*premio2)) )*(premio2-300))*(premio2-150)) ) 
f_prime = diff(f, L)
print(f_prime)
# Out:
# 0.745031436 - 1.89648087930495*exp(-0.005*premio2)/(1 + 1.89648087930495*exp(-0.005*premio2)) - 2.82921701435156*exp(-0.005*premio1)/(1 + 2.82921701435156*exp(-0.005*premio1))

# %%
f_prime
# Out:
# -1.89648087930495*(premio2 - 150)*exp(-0.005*premio2)*exp(premio2 - 300)/(1 + 1.89648087930495*exp(-0.005*premio2)) - 2.82921701435156*(premio1 - 150)*exp(-0.005*premio1)*exp(premio1 - 250)/(1 + 2.82921701435156*exp(-0.005*premio1))

# %%
def func(X):
    premio1 = X[0]
    premio2 = X[1]
    L  =      X[2] # this is the multiplier. lambda is a reserved keyword in python
    #return -0.0025 * 𝑃1**2 - 0.015 * 𝑃2**2 + 2.65 * 𝑃1 + 1.725 * 𝑃2 - 880 - L * (0.925 - 0.00125 * 𝑃1 - 0.00075 * 𝑃2)
    #return -0.0025 * 𝑃1**2 - 0.015 * 𝑃2**2 + 2.65 * 𝑃1 + 1.725 * 𝑃2 - 880 - L * (0.925 - 0.00125 * 𝑃1 - 0.00075 * 𝑃2)
    #return -0.0025 * 𝑃1**2 - 0.015 * 𝑃2**2 + 2.65 * 𝑃1 + 1.725 * 𝑃2 - 880 - L * (0.925 - 0.00125 * 𝑃1 - 0.00075 * 𝑃2)
    #return (sp.exp(1.04)*sp.exp(-0.005*P1) + 1) +  (L + 150)*0.005
    #return ((((sp.exp(1.04)*sp.exp(-0.005*premio1) ) /(1+sp.exp(1.04)*sp.exp(-0.005*premio1)))*(premio1-250)  )*(premio1-150)) +((((sp.exp(0.64)*sp.exp(-0.005*premio2) ) /(1+sp.exp(0.64)*sp.exp(-0.005*premio2)))*(premio2-300)  )*(premio2-150))-L*(((sp.exp(1.04)*sp.exp(-0.005*premio1) ) /(1+sp.exp(1.04)*sp.exp(-0.005*premio1))) + ((sp.exp(0.64)*sp.exp(-0.005*premio2) ) /(1+sp.exp(0.64)*sp.exp(-0.005*premio2)))-0.69647)

    return ((((sp.exp(1.04)*sp.exp(-0.005*premio1) ) /(1+sp.exp(1.04)*sp.exp(-0.005*premio1)))*(premio1-250)  )*(premio1-150)) +((((sp.exp(0.64)*sp.exp(-0.005*premio2) ) /(1+sp.exp(0.64)*sp.exp(-0.005*premio2)))*(premio2-300)  )*(premio2-150))-L*(((sp.exp(1.04)*sp.exp(-0.005*premio1) ) /(1+sp.exp(1.04)*sp.exp(-0.005*premio1))) + ((sp.exp(0.64)*sp.exp(-0.005*premio2) ) /(1+sp.exp(0.64)*sp.exp(-0.005*premio2)))-0.745031436)


def dfunc(X):
    dLambda = np.zeros(len(X))
    h = 1e-3 # this is the step size used in the finite difference.
    for i in range(len(X)):
        dX = np.zeros(len(X))
        dX[i] = h
        dLambda[i] = (func(X+dX)-func(X-dX))/(2*h);
    return dLambda

from scipy.optimize import fsolve

#this is the max
X1 = fsolve(dfunc, [500, 600, 0])
print(X1) ,
print(func(X1))
# Out:
# [   485.00300469    420.54246661 -63808.28813455]
# -870.911953837862

# %%
from sympy import symbols, diff
from sympy.solvers import solve

def lagrange_maximize_3d(obj_func, const_func, const_value):
    """Implementation of Lagrange Multipliers for maximizing
       functions subject to constraints.
       
       Here, I demonstrate how this method can be used to maximize functions with 3 variables
       subject to one constraint function in the same variables"""
    
    x, y, z, lambda0 = symbols('x y z lambda0', real=True)
    gradF = [diff(obj_func(x,y,z), x), diff(obj_func(x, y, z), y), diff(obj_func(x, y, z), z), const_func(x, y, z)]
    gradG = [diff(const_func(x,y,z), x), diff(const_func(x, y, z), y), diff(const_func(x, y, z), z), const_value]
    grad = []

    for i in range(0, len(gradF)):
    
        if(i != len(gradF) - 1):
            grad.append(gradF[i] - lambda0 * gradG[i])
        
        else:
            grad.append(gradF[i] - gradG[i])

    sol = solve(grad, x, y, z, lambda0)

    values = []
    for solution in sol:
        x0 = solution[0]
        y0 = solution[1]
        z0 = solution[2]
    
        values.append(obj_func(x0, y0, z0))
        
    sol_index = list.index(values, max(values))
    final_solution = sol[sol_index]
    
    print("Optimal values for maximizing the objective function when the constraint function equals " + str(const_value) + " : ")
    #print("")
    print("x : " + str(final_solution[0]))
    print("y : " + str(final_solution[1]))
    print("z : " + str(final_solution[2]))
    #print("")
    print("Maximum value of the objective function : " + str(obj_func(x0, y0, z0)))

# %%
surf = input("Enter value of constraint function : ")

# Example constraint function : g(x, y, z) = 2*(x*y + y*z + z*x). Surface area of a cuboidal box

def g(x, y, z):
    surf = 2*(x*y + y*z + z*x)
    return surf

# Example objective function : f(x, y, z) = x*y*z. Volume of a cuboidal box

def f(x, y, z):
    vol = x*y*z
    return vol
# Out:
# Enter value of constraint function : 24

# %%
#lagrange_maximize_3d(obj_func=f, const_func=g, const_value=surf)

# %%
#final_solution = sol[sol_index]

# %% [markdown]
# ##############################################

# %%
def f(x):
    return x**4 - 3*x**2


def fp(x):
    return 4*x**3 - 6*x

# Create 100 evenly spaced points between -2 and 2
x = np.linspace(-2., 2., 100)

# Evaluate the functions at x values
fx = f(x)
fpx = fp(x)

# Create plot
fig, ax = plt.subplots(1, 2)

ax[0].plot(x, fx)
ax[0].set_title("Function")

ax[1].plot(x, fpx)
ax[1].hlines(0.0, -2.5, 2.5, color="k", linestyle="--")
ax[1].set_title("Derivative")

for _ax in ax:
    _ax.spines["right"].set_visible(False)
    _ax.spines["top"].set_visible(False)

# %%
#https://datascience.quantecon.org/scientific/optimization.html

import scipy.optimize as opt

# For a scalar problem, we give it the function and the bounds between
# which we want to search
neg_min = opt.minimize_scalar(f, [-2, -0.5])
pos_min = opt.minimize_scalar(f, [0.5, 2.0])
print("The negative minimum is: \n", neg_min)
print("The positive minimum is: \n", pos_min)
# Out:
# The negative minimum is:
#   message:
#           Optimization terminated successfully;
#           The returned value satisfies the termination criteria
#           (using xtol = 1.48e-08 )
#  success: True
#      fun: -2.2499999999999996
#        x: -1.2247448697638397
#      nit: 12
#     nfev: 15
# The positive minimum is:
#   message:
#           Optimization terminated successfully;
#           The returned value satisfies the termination criteria
#           (using xtol = 1.48e-08 )
#  success: True
#      fun: -2.2499999999999996
#        x: 1.2247448697638397
#      nit: 12
#     nfev: 15

# %%
# Create a function that evaluates to negative f
def neg_f(x):
    return -f(x)

max_out = opt.minimize_scalar(neg_f, [-0.35, 0.35])
print("The maximum is: \n", max_out)
# Out:
# The maximum is:
#   message:
#           Optimization terminated successfully;
#           The returned value satisfies the termination criteria
#           (using xtol = 1.48e-08 )
#  success: True
#      fun: 1.1519919564363613e-23
#        x: 1.9595849530247992e-12
#      nit: 9
#     nfev: 12

# %%
def U(A, B, alpha=1/3):
    return B**alpha * A**(1-alpha)

fig, ax = plt.subplots()
B = 1.5
A = np.linspace(1, 10, 100)
ax.plot(A, U(A, B))
ax.set_xlabel("A")
ax.set_ylabel("U(B=1.5, A)")
# Out:
# Text(0, 0.5, 'U(B=1.5, A)')

# %%
fig, ax = plt.subplots()
B = np.linspace(1, 20, 100).reshape((100, 1))
contours = ax.contourf(A, B.flatten(), U(A, B))
fig.colorbar(contours)
ax.set_xlabel("A")
ax.set_ylabel("B")
ax.set_title("U(A,B)")
# Out:
# Text(0.5, 1.0, 'U(A,B)')

# %%
n_pa = 50
prices_A = np.linspace(0.5, 5.0, n_pa)
W = 20

# %%
prices_A
# Out:
# array([0.5       , 0.59183673, 0.68367347, 0.7755102 , 0.86734694,
#        0.95918367, 1.05102041, 1.14285714, 1.23469388, 1.32653061,
#        1.41836735, 1.51020408, 1.60204082, 1.69387755, 1.78571429,
#        1.87755102, 1.96938776, 2.06122449, 2.15306122, 2.24489796,
#        2.33673469, 2.42857143, 2.52040816, 2.6122449 , 2.70408163,
#        2.79591837, 2.8877551 , 2.97959184, 3.07142857, 3.16326531,
#        3.25510204, 3.34693878, 3.43877551, 3.53061224, 3.62244898,
#        3.71428571, 3.80612245, 3.89795918, 3.98979592, 4.08163265,
#        4.17346939, 4.26530612, 4.35714286, 4.44897959, 4.54081633,
#        4.63265306, 4.7244898 , 4.81632653, 4.90816327, 5.        ])

# %%
def A_indifference(B, ubar, alpha=1/3):
    return ubar**(1/(1-alpha)) * B**(-alpha/(1-alpha))

def plot_indifference_curves(ax, alpha=1/3):
    ubar = np.arange(1, 11, 2)
    ax.plot(B, A_indifference(B, ubar, alpha))
    ax.legend([r"$\bar{U}$" + " = {}".format(i) for i in ubar])
    ax.set_xlabel("B")
    ax.set_ylabel(r"$A(B, \bar{U}$)")

fig, ax = plt.subplots()
plot_indifference_curves(ax)

# %%
def A_bc(B, W=20, pa=2):
    "Given B, W, and pa return the max amount of A our consumer can afford"
    return (W - B) / pa

def plot_budget_constraint(ax, W=20, pa=2):
    B_bc = np.array([0, W])
    A = A_bc(B_bc, W, pa)
    ax.plot(B_bc, A)
    ax.fill_between(B_bc, 0, A, alpha=0.2)
    ax.set_xlabel("B")
    ax.set_ylabel("A")
    return ax

fig, ax = plt.subplots()
plot_budget_constraint(ax, 20, 2)
# Out:
# <Axes: xlabel='B', ylabel='A'>

# %%
fig, ax = plt.subplots()
plot_indifference_curves(ax)
plot_budget_constraint(ax)
# Out:
# <Axes: xlabel='B', ylabel='A'>

# %%
from scipy.optimize import minimize_scalar

def objective(B, W=20, pa=2):
    """
    Return value of -U for a given B, when we consume as much A as possible

    Note that we return -U because scipy wants to minimize functions,
    and the value of B that minimizes -U will maximize U
    """
    A = A_bc(B, W, pa)
    return -U(A, B)

result = minimize_scalar(objective)
optimal_B = result.x
optimal_A = A_bc(optimal_B, 20, 2)
optimal_U = U(optimal_A, optimal_B)

print("The optimal U is ", optimal_U)
print("and was found at (A,B) =", (optimal_A, optimal_B))
# Out:
# The optimal U is  6.666666666666667
# and was found at (A,B) = (6.666666630651958, 6.666666738696083)

# %%
# Create various prices
n_pa = 50
prices_A = np.linspace(0.5, 5.0, n_pa)
W = 20

# Create lists to store the results of the optimal A and B calculation
optimal_As = []
optimal_Bs = []
for pa in prices_A:
    result = minimize_scalar(objective, args=(W, pa))
    opt_B_val = result.x

    optimal_Bs.append(opt_B_val)
    optimal_As.append(A_bc(opt_B_val, W, pa))

fig, ax = plt.subplots()

ax.plot(prices_A, optimal_As, label="Purchased Apples")
ax.plot(prices_A, optimal_Bs, label="Purchased Bananas")
ax.set_xlabel("Price of Apples")
ax.legend()

# %% [markdown]
# ############################################

# %%
#https://onecompiler.com/python/3zd5jcrjb
import sympy as sp

def lagrange_multiplier(obj_func, constraint_eqns, variables):
    # Create the Lagrange multiplier symbol
    lambda_ = sp.symbols('lambda_')

    # Create the Lagrangian function
    lagrangian = obj_func + lambda_ * constraint_eqns

    # Compute the partial derivatives of the Lagrangian with respect to the variables and lambda
    partial_derivatives = [sp.diff(lagrangian, var) for var in variables] + [sp.diff(lagrangian, lambda_)]

    # Find the critical points by solving the partial derivative equations
    critical_points = sp.solve(partial_derivatives, variables + [lambda_], dict=True)

    return critical_points

# %%
# Define the objective function, constraint equations, and variables
x, y = sp.symbols('x y')
obj_func = 10 * x**2 + 6 * y**2
constraint_eqns = [x**2 * y**2 - 20]
variables = [x, y]

# Solve the optimization problem using Lagrange multiplier
solutions = lagrange_multiplier(obj_func, constraint_eqns, variables)

# Print the solutions
for sol in solutions:
    print(f"Solution: {sol}")
    print(f"Objective Function Value: {obj_func.subs(sol)}")
    print("-------------------------")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[221], line 8
#       5 variables = [x, y]
#       7 # Solve the optimization problem using Lagrange multiplier
# ----> 8 solutions = lagrange_multiplier(obj_func, constraint_eqns, variables)
#      10 # Print the solutions
#      11 for sol in solutions:
#
# Cell In[220], line 9, in lagrange_multiplier(obj_func, constraint_eqns, variables)
#       6 lambda_ = sp.symbols('lambda')
#       8 # Create the Lagrangian function
# ----> 9 lagrangian = 'obj_func' + 'lambda_' * 'constraint_eqns'
#      11 # Compute the partial derivatives of the Lagrangian with respect to the variables and lambda
#      12 partial_derivatives = [sp.diff(lagrangian, var) for var in variables] + [sp.diff(lagrangian, lambda_)]
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
obj_func = 10 * x**2 + 6 * y**2

# %%
obj_func
# Out:
# 10.5*x**1.5 + 6.2*y**0.7

# %%
constraint_eqns = [x**2 * y**2 - 20]
constraint_eqns
# Out:
# [x**2*y**2 - 20]

# %%
lambda_ = sp.symbols('lambda')
lambda_
# Out:
# lambda

# %%
cliente = {
    'X': [1, 0],
    'Preco': [250, 300]
}

df = pd.DataFrame(cliente)

# %%
df
# Out:
#    X  Preco
# 0  1    250
# 1  0    300

# %%
# Define the demand function
def demand(X,Preco):
    demanda=[]
    demanda = np.exp(0.64+0.4*X - 0.005*Preco)/((1+np.exp(0.64+0.4*X - 0.005*Preco)))
    d = demanda.append(demanda)
    return d

# %%
#demand(1,250)

# %%
x = symbols('x')
C = symbols('C')
a = symbols('a')
b = symbols('b')
b = symbols('b')
L = symbols('L')
premio1 = symbols('premio1')
premio2 = symbols('premio2')

#f =np.exp(0.64 - 0.005*premio1)/(1+np.exp(0.64 - 0.005*premio1))

f =((((sp.exp(1.04)*sp.exp(-0.005*premio1) ) /(1+sp.exp(1.04)*sp.exp(-0.005*premio1)))*(premio1-250)  )*(premio1-150)) +((((sp.exp(0.64)*sp.exp(-0.005*premio2) ) /(1+sp.exp(0.64)*sp.exp(-0.005*premio2)))*(premio2-300)  )*(premio2-150))-L*(((sp.exp(1.04)*sp.exp(-0.005*premio1) ) /(1+sp.exp(1.04)*sp.exp(-0.005*premio1))) + ((sp.exp(0.64)*sp.exp(-0.005*premio2) ) /(1+sp.exp(0.64)*sp.exp(-0.005*premio2)))-0.745031436)


#f =(
#    ( ((sp.exp(1.04)*sp.exp(-0.005*premio1) ) /(1+sp.exp(1.04)*sp.exp(-0.005*premio1)))*sp.exp(premio1-250) )*sp.exp(premio1-150) +  
#    ( ((sp.exp(0.64)*sp.exp(-0.005*premio2) ) /(1+sp.exp(0.64)*sp.exp(-0.005*premio2)))*sp.exp(premio2-300) )*sp.exp(premio2-150)
#)-L*(
#    ( ((sp.exp(1.04)*sp.exp(-0.005*premio1) ) /(1+sp.exp(1.04)*sp.exp(-0.005*premio1)))*sp.exp(premio1-250) )*sp.exp(premio1-150) +  
#    ( ((sp.exp(0.64)*sp.exp(-0.005*premio2) ) /(1+sp.exp(0.64)*sp.exp(-0.005*premio2)))*sp.exp(premio2-300) )*sp.exp(premio2-150)
#)
 #f =(((((sp.exp(1.04)*sp.exp(-0.005*premio1) ) /(1+sp.exp(1.04)*sp.exp(-0.005*premio1)) )*(premio1-250))*(premio1-150)) +
#   ((((sp.exp(0.64)*sp.exp(-0.005*premio2) ) /(1+sp.exp(0.64)*sp.exp(-0.005*premio2)) )*(premio2-300))*(premio2-150)) )-L*(((((sp.exp(1.04)*sp.exp(-0.005*premio1) ) /(1+sp.exp(1.04)*sp.exp(-0.005*premio1)) )*(premio1-250))*(premio1-150)) +
#   ((((sp.exp(0.64)*sp.exp(-0.005*premio2) ) /(1+sp.exp(0.64)*sp.exp(-0.005*premio2)) )*(premio2-300))*(premio2-150)) ) 
f_prime = diff(f, L)
print(f_prime)

# %%
#https://notebook.community/IBMDecisionOptimization/docplex-examples/examples/mp/jupyter/oil_blending
import numpy as np

gas_names = ["super", "regular", "diesel"]

gas_data = np.array([[3000, 70, 10, 1], [2000, 60, 8, 2], [1000, 50, 6, 1]])

oil_names = ["crude1", "crude2", "crude3"]

oil_data = np.array([[5000, 45, 12, 0.5], [5000, 35, 6, 2], [5000, 25, 8, 3]])

nb_gas  = len(gas_names)
nb_oils = len(oil_names)
range_gas = range(nb_gas)
range_oil = range(nb_oils)
print("Number of gasoline types = {0}".format(nb_gas))
print("Number of crude types = {0}".format(nb_oils))

# global data
production_cost = 4
production_max = 14000
# each $1 spent on advertising increases demand by 10.
advert_return = 10
# Out:
# Number of gasoline types = 3
# Number of crude types = 3

# %%
import pandas as pd
gaspd = pd.DataFrame([(gas_names[i],int(gas_data[i][0]),int(gas_data[i][1]),int(gas_data[i][2]),int(gas_data[i][3])) 
                      for i in range_gas])
oilpd = pd.DataFrame([(oil_names[i],int(oil_data[i][0]),int(oil_data[i][1]),int(oil_data[i][2]),oil_data[i][3]) 
                      for i in range_oil])
gaspd.columns = ['name','demand','price','octane','lead']
oilpd.columns= ['name','capacity','price','octane','lead']

# %%
gaspd
# Out:
#       name  demand  price  octane  lead
# 0    super    3000     70      10     1
# 1  regular    2000     60       8     2
# 2   diesel    1000     50       6     1

# %%
oilpd
# Out:
#      name  capacity  price  octane  lead
# 0  crude1      5000     45      12   0.5
# 1  crude2      5000     35       6   2.0
# 2  crude3      5000     25       8   3.0

# %%
import autograd.numpy as np
from autograd import grad
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[275], line 1
# ----> 1 import autograd.numpy as np
#       2 from autograd import grad
#
# ModuleNotFoundError: No module named 'autograd'

# %%
#!pip install autograd

# %%
#https://stackoverflow.com/questions/9876290/how-do-i-compute-derivative-using-numpy
dx = 0.01
x = np.arange(-4, 4+dx, dx)
y = np.sin(x)
n = np.size(x)

# %%
# Out:
# int

# %%
yp = np.zeros(n)
yp[0] = (-3*y[0] + 4*y[1] - y[2]) / (2*dx)
yp[n-1] = (3 * y[n-1] - 4*y[n-2] + y[n-3]) / (2*dx)
for j in range(1,n-1):
    yp[j] = (y[j+1] - y[j-1]) / (2*dx)

# %%
yp
# Out:
# array([-6.53665597e-01, -6.61167818e-01, -6.68636793e-01, -6.76038905e-01,
#        -6.83373414e-01, -6.90639586e-01, -6.97836694e-01, -7.04964020e-01,
#        -7.12020849e-01, -7.19006477e-01, -7.25920205e-01, -7.32761342e-01,
#        -7.39529203e-01, -7.46223112e-01, -7.52842399e-01, -7.59386403e-01,
#        -7.65854468e-01, -7.72245949e-01, -7.78560205e-01, -7.84796607e-01,
#        -7.90954529e-01, -7.97033357e-01, -8.03032482e-01, -8.08951304e-01,
#        -8.14789232e-01, -8.20545681e-01, -8.26220077e-01, -8.31811852e-01,
#        -8.37320445e-01, -8.42745308e-01, -8.48085897e-01, -8.53341678e-01,
#        -8.58512125e-01, -8.63596722e-01, -8.68594960e-01, -8.73506339e-01,
#        -8.78330368e-01, -8.83066565e-01, -8.87714456e-01, -8.92273577e-01,
#        -8.96743470e-01, -9.01123691e-01, -9.05413799e-01, -9.09613367e-01,
#        -9.13721974e-01, -9.17739210e-01, -9.21664673e-01, -9.25497970e-01,
# ...

# %%
#https://svitla.com/blog/numerical-differentiation-methods-in-python
import numpy
import matplotlib.pyplot as plt
 
def f(x):
 return x*x
 
x = numpy.arange(0,4,0.01)
y = f(x)
 
plt.figure(figsize=(10,5))
plt.plot(x, y, 'b')
plt.grid(axis = 'both')
plt.show()

# %%
# Define the demand function
def f2(x,price):
    return np.exp(0.64+0.4*x - 0.005*price)/((1+np.exp(0.64+0.4*x - 0.005*price)))

x=np.random.binomial(1, 0.5,100)
price =  np.random.randint(50, 1000,100)
price = np.sort(price)

y = f2(x,price)

# %%
price
# Out:
# array([ 59,  63,  81,  83,  89,  89,  90,  97, 109, 121, 122, 125, 138,
#        140, 147, 148, 163, 166, 178, 184, 185, 209, 210, 214, 234, 239,
#        239, 240, 242, 280, 291, 294, 294, 311, 317, 329, 329, 338, 342,
#        350, 360, 361, 377, 384, 385, 387, 398, 402, 410, 427, 431, 436,
#        440, 445, 451, 451, 463, 470, 472, 475, 491, 495, 496, 500, 525,
#        543, 573, 603, 621, 632, 632, 636, 653, 659, 662, 663, 666, 673,
#        704, 713, 725, 756, 786, 805, 812, 825, 833, 837, 847, 859, 869,
#        885, 889, 906, 910, 942, 946, 958, 962, 995])

# %%
plt.figure(figsize=(10,5))
plt.plot(price, y, 'b')
plt.grid(axis = 'both')
plt.show()

# %%
#https://pythonnumericalmethods.studentorg.berkeley.edu/notebooks/chapter20.02-Finite-Difference-Approximating-Derivatives.html
# step size
#h = 0.1
h = 1e-3
# define grid
x = np.arange(0, 2*np.pi, h) 
# compute function
y = np.cos(x) 

# compute vector of forward differences
forward_diff = np.diff(y)/h 
# compute corresponding grid
x_diff = x[:-1:] 
# compute exact solution
exact_solution = -np.sin(x_diff) 

# Plot solution
plt.figure(figsize = (12, 8))
plt.plot(x_diff, forward_diff, '--', \
         label = 'Finite difference approximation')
plt.plot(x_diff, exact_solution, \
         label = 'Exact solution')
plt.legend()
plt.show()

# Compute max error between 
# numerical derivative and exact solution
max_error = max(abs(exact_solution - forward_diff))
print(max_error)
# Out:
# 0.0004999999692957724

# %%
#h = 0.1
h = 1e-3
# define grid
x = np.arange(0, 2*np.pi, h) 
# compute function
y = np.cos(x) 
x
# Out:
# array([0.000e+00, 1.000e-03, 2.000e-03, ..., 6.281e+00, 6.282e+00,
#        6.283e+00])

# %%
plt.plot(x)

# %%
#https://hplgit.github.io/fem-book/doc/pub/book/pdf/fem-book-4print-2up.pdf
import sympy as sym
x, h, lam = sym.symbols("x h \lambda")
basis = [1 - x/h, x/h]
for i in range(len(basis)):
phi_i = basis[i]
for j in range(len(basis)):
phi_j = basis[j]
a = sym.integrate(sym.diff(phi_i, x)*sym.diff(phi_j, x), (x, 0, h))
a -= (sym.diff(phi_i, x)*phi_j).subs(x,0)
a -= (sym.diff(phi_j, x)*phi_i).subs(x,0)
a += (lam*phi_j*phi_i).subs(x,0)

# %%
def f(x):
    return x**2 + 1
for i in range(1, n-1):
    u2[i] = u[i-1] - 2*u[i] + u[i+1] + f(x[i])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 n = u.size
#       2 for i in range(0, n-1):
#       3     d[i] = u[i+1] - u[i]
#
# NameError: name 'u' is not defined

# %%
# Create an array of integers from 0 to 10
quantity = np.arange(10)

# Define the cost function
def cost(q): 
  return 50-5*(q-2)**2

# Plot cost versus quantity
plt.plot(quantity, cost(quantity))
plt.xlabel('Quantity (thousands)')
plt.ylabel('Cost ($ K)')
plt.show()

# %%
# Calculate the profit for every quantity
profits = profit(quantity)

# Find the maximum profit
max_profit = profits.max()

# Find the optimal quantity
max_profit_ind = np.argmax(profits)
optimal_quantity = quantity[max_profit_ind]

# Print the results
print(f"You need to print {optimal_quantity * 1000} magazines to make the maximum profit of ${max_profit * 1000}.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[64], line 2
#       1 # Calculate the profit for every quantity
# ----> 2 profits = profit(quantity)
#       4 # Find the maximum profit
#       5 max_profit = profits.max()
#
# NameError: name 'profit' is not defined

# %%
# !pip install gekko
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from scipy.optimize import linprog
c = [-100, -125]
A = [[3, 6], [8, 4]]
b = [30, 44]
bound = (0, None)
res = linprog(c, A_ub=A, b_ub=b, bounds=[bound, bound], method='highs')

# print solution
print(f'Optimal solution: G = {res.x[0]:.2f}, H = {res.x[1]:.2f}')
print(f'Maximum profit = $ {-res.fun:.2f}')
# Out:
# Optimal solution: G = 4.00, H = 3.00
# Maximum profit = $ 775.00

# %%
from gekko import GEKKO
m = GEKKO()
G,H = m.Array(m.Var,2,lb=0)
m.Maximize(100*G+125*H)
m.Equation(3*G+6*H<=30)
m.Equation(8*G+4*H<=44)
m.solve(disp=False)

# print solution
print(f'Optimal solution: G = {G.value[0]:.2f}, H = {H.value[0]:.2f}')
print(f'Maximum profit = $ {-m.options.objfcnval:.2f}')
# Out:
# Optimal solution: G = 4.00, H = 3.00
# Maximum profit = $ 775.00

# %%
import numpy as np
import matplotlib.pyplot as plt
# visualize solution
g = np.linspace(1,3,200)
h = np.linspace(2,3,200)
x,y = np.meshgrid(g,h)
obj = x*y**2-x**2-y**2
plt.imshow(((x+y>=4)&(x*y<=5)&(x>=0)&(y>=0)).astype(int), 
    extent=(x.min(),x.max(),y.min(),y.max()),origin='lower',cmap='Greys',alpha=0.3);
# plot constraints
x0 = np.linspace(1,3,2000)

y0 = 4-x0    # x+y>=4
y1 = 5.0/x0  # x*y<=5

plt.plot(x0,y0,':',color='orange',linewidth=2,label=r'$x+y\geq4$')
plt.plot(x0,y1,'k--',linewidth=2,label=r'$xy\leq5$')

plt.plot([1,1],[2,3],'b-',label=r'$x\geq1$')
plt.plot([3,3],[2,3],'b:',label=r'$x\leq3$')
plt.plot([1,3],[2,2],'k-',label=r'$y\geq2$')
plt.plot(x0, 3*np.ones_like(x0),'k:',label=r'$y\leq3$')
# objective contours
CS = plt.contour(x,y,obj,np.round(np.linspace(0,10,21),1))
plt.clabel(CS, inline=1, fontsize=10)
plt.xlim(0.9,3.1); plt.ylim(1.9,3.1); plt.grid(); plt.tight_layout()
plt.legend(loc=1); plt.xlabel('x'); plt.ylabel('y')
plt.show()

# %%
from gekko import GEKKO
m = GEKKO(remote=False)
x = m.Array(m.Var,3,lb=0)
x1,x2,x3 = x
m.Minimize(1000-x1**2-2*x2**2-x3**2-x1*x2-x1*x3)
m.Equations([8*x1+14*x2+7*x3==56,
             x1**2+x2**2+x3**2>=25])
m.solve(disp=False)
res=[print(f'x{i+1}: {xi.value[0]}') for i,xi in enumerate(x)]
print(f'Objective: {m.options.objfcnval:.2f}')
# Out:
# x1: 7.0000000234
# x2: 0.0
# x3: 0.0
# Objective: 951.00

# %%
import numpy as np
import threading
import time, random
from gekko import GEKKO

class ThreadClass(threading.Thread):
    def __init__(self, id, xg):
        s = self
        s.id = id
        s.m = GEKKO(remote=False)
        s.xg = xg
        s.objective = float('NaN')

        # initialize variables
        s.m.x = s.m.Array(s.m.Var,3,lb=0)
        for i in range(3):
            s.m.x[i].value = xg[i]
        s.m.x1,s.m.x2,s.m.x3 = s.m.x

        # Equations
        s.m.Equation(8*s.m.x1+14*s.m.x2+7*s.m.x3==56)
        s.m.Equation(s.m.x1**2+s.m.x2**2+s.m.x3**2>=25)

        # Objective
        s.m.Minimize(1000-s.m.x1**2-2*s.m.x2**2-s.m.x3**2
                     -s.m.x1*s.m.x2-s.m.x1*s.m.x3)

        # Set solver option
        s.m.options.SOLVER = 1

        threading.Thread.__init__(s)

    def run(self):
        print('Running application ' + str(self.id) + '\n')
        self.m.solve(disp=False,debug=0) # solve
        # Retrieve objective if successful
        if (self.m.options.APPSTATUS==1):
            self.objective = self.m.options.objfcnval
        else:
            self.objective = float('NaN')
        self.m.cleanup()

# Optimize at mesh points
x1_ = np.arange(0.0, 10.0, 3.0)
x2_ = np.arange(0.0, 10.0, 3.0)
x3_ = np.arange(0.0, 10.0, 3.0)
x1,x2,x3 = np.meshgrid(x1_,x2_,x3_)

threads = [] # Array of threads

# Load applications
id = 0
for i in range(x1.shape[0]):
    for j in range(x1.shape[1]):
        for k in range(x1.shape[2]):
            xg = (x1[i,j,k],x2[i,j,k],x3[i,j,k])
            # Create new thread
            threads.append(ThreadClass(id, xg))
            # Increment ID
            id += 1

# Run applications simultaneously as multiple threads
# Max number of threads to run at once
max_threads = 8
for t in threads:
    while (threading.activeCount()>max_threads):
        # check for additional threads every 0.01 sec
        time.sleep(0.01)
    # start the thread
    t.start()

# Check for completion
mt = 10.0 # max time (sec)
it = 0.0  # time counter
st = 1.0  # sleep time (sec)
while (threading.active_count()>=3):
    time.sleep(st)
    it = it + st
    print('Active Threads: ' + str(threading.active_count()))
    # Terminate after max time
    if (it>=mt):
        break

# Initialize array for objective
obj = np.empty_like(x1)

# Retrieve objective results
id = 0
id_best = 0; obj_best = 1e10
for i in range(x1.shape[0]):
    for j in range(x1.shape[1]):
        for k in range(x1.shape[2]):
            obj[i,j,k] = threads[id].objective
            if obj[i,j,k]<obj_best:
                id_best = id
                obj_best = obj[i,j,k]
            id += 1
# Out:
# C:\Users\flcoelho\AppData\Local\Temp\ipykernel_23176\2408188917.py:66: DeprecationWarning: activeCount() is deprecated, use active_count() instead
#   while (threading.activeCount()>max_threads):
# Running application 0
#
# Running application 1
#
# Running application 2
#
# Running application 3
#
# Running application 4
#
# Running application 5
#
# Running application 6
#
# Running application 7
#
# Running application 8
#
# Running application 9
#
# Running application 10
#
# Running application 11
#
# Running application 12
#
# Running application 13
#
# Running application 14
# Running application 15
#
#
# Running application 16
#
# Running application 17
#
# Running application 18
#
# Running application 19
#
# Running application 20
#
# Running application 21
#
# Running application 22
#
# Running application 23
#
# Running application 24
#
# Running application 25
#
# Running application 26
#
# Running application 27
#
# Running application 28
#
# Running application 29
#
# ...

# %%
# all solutions
print(obj)
# Out:
# [[[951. 936. 936. 936.]
#   [951. 936. 936. 936.]
#   [951. 936. 936. 936.]
#   [951. 951. 951. 936.]]
#
#  [[ nan 936. 936. 936.]
#   [951. 936. 936. 936.]
#   [951. 951. 936. 936.]
#   [951. 951. 951. 936.]]
#
#  [[ nan  nan 936. 936.]
#   [ nan  nan 936. 936.]
#   [951. 951. 936. 936.]
#   [951. 951. 951. 936.]]
#
#  [[ nan  nan 936. 936.]
#   [ nan  nan 936. 936.]
#   [951. 951. 936. 936.]
#   [951. 951. 951. 936.]]]

# %%
print(f'Best objective {obj_best}')
print(f'Solution {threads[id_best].m.x}')
# Out:
# Best objective 936.0
# Solution [[0.0] [0.0] [8.0]]

# %%
from gekko import GEKKO
from hyperopt import fmin, tpe, hp
from hyperopt import STATUS_OK, STATUS_FAIL

# Define the search space for the hyperparameters
space = {'x1': hp.quniform('x1', 0, 10, 3),
         'x2': hp.quniform('x2', 0, 10, 3),
         'x3': hp.quniform('x3', 0, 10, 3)}

def objective(params):
    m = GEKKO(remote=False)
    x = m.Array(m.Var,3,lb=0)
    x1,x2,x3 = x
    x1.value = params['x1']
    x2.value = params['x2']
    x3.value = params['x3']
    m.Minimize(1000-x1**2-2*x2**2-x3**2-x1*x2-x1*x3)
    m.Equations([8*x1+14*x2+7*x3==56,
                 x1**2+x2**2+x3**2>=25])
    m.options.SOLVER = 1
    m.solve(disp=False,debug=False)
    obj = m.options.objfcnval
    if m.options.APPSTATUS==1:
        s=STATUS_OK
    else:
        s=STATUS_FAIL
    m.cleanup()
    return {'loss':obj, 'status': s, 'x':x}

best = fmin(objective, space, algo=tpe.suggest, max_evals=50)
# Out:
# 100%|█████████████████████████████████████████████████████████████| 50/50 [00:03<00:00, 12.94trial/s, best loss: 936.0]

# %%
# !pip install hyperopt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 1.6/1.6 MB 16.9 MB/s eta 0:00:00
# ...
#   WARNING: The script hyperopt-mongo-worker.exe is installed in 'C:\Users\flcoelho\AppData\Roaming\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
print(best)
# Out:
# {'x1': 6.0, 'x2': 9.0, 'x3': 6.0}

# %%
sol = objective(best)
print(f"Solution Status: {sol['status']}")
print(f"Objective: {sol['loss']:.2f}")
print(f"Solution: {sol['x']}")
# Out:
# Solution Status: ok
# Objective: 936.00
# Solution: [[0.0] [0.0] [8.0]]

# %%
space = {'x1': hp.quniform('x1', 0, 10, 3),
         'x2': hp.quniform('x2', 0, 10, 3),
         'x3': hp.quniform('x3', 0, 10, 3)}

# %%
space
# Out:
# {'x1': <hyperopt.pyll.base.Apply at 0x296b44ce650>,
#  'x2': <hyperopt.pyll.base.Apply at 0x296b44cec20>,
#  'x3': <hyperopt.pyll.base.Apply at 0x296b44cd6c0>}
